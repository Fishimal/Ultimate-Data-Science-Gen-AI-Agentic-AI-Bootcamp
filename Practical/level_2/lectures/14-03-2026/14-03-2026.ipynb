# %%
import sqlite3

# %% [markdown]
# Step 1: Connect to database file (.db file)
#
#                   If no file present
#                       Create the Database file
#
# Step 2: Connect db connection with cursor object
#
#                   cursor = conn.cursor()
